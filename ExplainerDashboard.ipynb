# %%
# !pip install explainerdashboard
# Out:
# Collecting explainerdashboard
#   Downloading explainerdashboard-0.3.5-py3-none-any.whl (287 kB)
# Requirement already satisfied: dash-bootstrap-components in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (0.12.0)
# Requirement already satisfied: waitress in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (2.0.0)
# Requirement already satisfied: scikit-learn in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (0.23.2)
# Requirement already satisfied: numpy in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (1.19.5)
# Collecting oyaml
#   Downloading oyaml-1.0-py2.py3-none-any.whl (3.0 kB)
# Requirement already satisfied: joblib in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (0.16.0)
# Requirement already satisfied: shap>=0.37 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (0.39.0)
# Collecting dtreeviz>=1.3
#   Downloading dtreeviz-1.3.tar.gz (60 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (1.1.2)
# Collecting flask-simplelogin
#   Downloading flask_simplelogin-0.0.7-py2.py3-none-any.whl (18 kB)
# Collecting dash-auth
#   Downloading dash_auth-1.4.1.tar.gz (470 kB)
# Requirement already satisfied: dash>=1.19 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (1.20.0)
# Requirement already satisfied: click in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from explainerdashboard) (7.1.2)
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from scikit-learn->explainerdashboard) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from scikit-learn->explainerdashboard) (2.1.0)
# Requirement already satisfied: pyyaml in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from oyaml->explainerdashboard) (5.3.1)
# Requirement already satisfied: cloudpickle in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from shap>=0.37->explainerdashboard) (1.6.0)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from shap>=0.37->explainerdashboard) (4.50.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from shap>=0.37->explainerdashboard) (0.0.7)
# Requirement already satisfied: numba in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from shap>=0.37->explainerdashboard) (0.51.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (0.16)
# Requirement already satisfied: matplotlib in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dtreeviz>=1.3->explainerdashboard) (3.4.2)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting pytest
#   Downloading pytest-6.2.4-py3-none-any.whl (280 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from pandas>=1.1->explainerdashboard) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from pandas>=1.1->explainerdashboard) (2.8.1)
# Collecting flask_wtf
#   Downloading Flask_WTF-0.14.3-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: Flask>=0.12 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from flask-simplelogin->explainerdashboard) (1.1.2)
# Collecting chart_studio>=1.0.0
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: flask-compress in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash-auth->explainerdashboard) (1.9.0)
# Collecting flask-seasurf
#   Downloading Flask_SeaSurf-0.3.0-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: requests in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash-auth->explainerdashboard) (2.24.0)
# Requirement already satisfied: retrying in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash-auth->explainerdashboard) (1.3.3)
# Requirement already satisfied: itsdangerous>=1.1.0 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash-auth->explainerdashboard) (1.1.0)
# Requirement already satisfied: ua_parser in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash-auth->explainerdashboard) (0.10.0)
# Requirement already satisfied: dash-core-components==1.16.0 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash>=1.19->explainerdashboard) (1.16.0)
# Requirement already satisfied: dash-renderer==1.9.1 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash>=1.19->explainerdashboard) (1.9.1)
# Requirement already satisfied: plotly in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash>=1.19->explainerdashboard) (4.14.3)
# Requirement already satisfied: dash-html-components==1.1.3 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash>=1.19->explainerdashboard) (1.1.3)
# Requirement already satisfied: future in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash>=1.19->explainerdashboard) (0.18.2)
# Requirement already satisfied: dash-table==4.11.3 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from dash>=1.19->explainerdashboard) (4.11.3)
# Requirement already satisfied: ipython in c:\users\rishav\appdata\roaming\python\python37\site-packages (from jupyter-dash->explainerdashboard) (7.18.1)
# Requirement already satisfied: ipykernel in c:\users\rishav\appdata\roaming\python\python37\site-packages (from jupyter-dash->explainerdashboard) (5.3.4)
# Collecting ansi2html
#   Downloading ansi2html-1.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: setuptools in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (49.6.0.post20200814)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from numba->shap>=0.37->explainerdashboard) (0.34.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (8.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from matplotlib->dtreeviz>=1.3->explainerdashboard) (1.2.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (0.4.3)
# Requirement already satisfied: packaging in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (20.4)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (1.7.0)
# Collecting py>=1.8.2
#   Using cached py-1.10.0-py2.py3-none-any.whl (97 kB)
# Collecting atomicwrites>=1.0; sys_platform == "win32"
#   Using cached atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (20.1.0)
# Requirement already satisfied: toml in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from pytest->dtreeviz>=1.3->explainerdashboard) (0.10.2)
# Collecting iniconfig
#   Using cached iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pluggy<1.0.0a1,>=0.12
#   Using cached pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: six>=1.5 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.7.3->pandas>=1.1->explainerdashboard) (1.15.0)
# Collecting WTForms
#   Downloading WTForms-2.3.3-py2.py3-none-any.whl (169 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from Flask>=0.12->flask-simplelogin->explainerdashboard) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from Flask>=0.12->flask-simplelogin->explainerdashboard) (0.16.1)
# Requirement already satisfied: brotli in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from flask-compress->dash-auth->explainerdashboard) (1.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->dash-auth->explainerdashboard) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->dash-auth->explainerdashboard) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->dash-auth->explainerdashboard) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->dash-auth->explainerdashboard) (1.25.10)
# Requirement already satisfied: decorator in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipython->jupyter-dash->explainerdashboard) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipython->jupyter-dash->explainerdashboard) (5.0.4)
# Requirement already satisfied: backcall in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipython->jupyter-dash->explainerdashboard) (3.0.7)
# Requirement already satisfied: pygments in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipython->jupyter-dash->explainerdashboard) (2.7.1)
# Requirement already satisfied: jedi>=0.10 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipython->jupyter-dash->explainerdashboard) (0.17.2)
# Requirement already satisfied: jupyter-client in c:\users\rishav\appdata\roaming\python\python37\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from ipykernel->jupyter-dash->explainerdashboard) (6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->dtreeviz>=1.3->explainerdashboard) (3.1.0)
# Requirement already satisfied: MarkupSafe in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from WTForms->flask_wtf->flask-simplelogin->explainerdashboard) (1.1.1)
# Requirement already satisfied: ipython-genutils in c:\users\rishav\appdata\roaming\python\python37\site-packages (from traitlets>=4.2->ipython->jupyter-dash->explainerdashboard) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\rishav\appdata\roaming\python\python37\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->explainerdashboard) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from jedi>=0.10->ipython->jupyter-dash->explainerdashboard) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from jupyter-client->ipykernel->jupyter-dash->explainerdashboard) (4.6.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\rishav\appdata\roaming\python\python37\site-packages (from jupyter-client->ipykernel->jupyter-dash->explainerdashboard) (19.0.2)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\rishav\anaconda3\envs\tensorflow_env\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash->explainerdashboard) (227)
# Building wheels for collected packages: dtreeviz, dash-auth
#   Building wheel for dtreeviz (setup.py): started
#   Building wheel for dtreeviz (setup.py): finished with status 'done'
#   Created wheel for dtreeviz: filename=dtreeviz-1.3-py3-none-any.whl size=66643 sha256=f41b371943a65741b9f67f4ae0d245dfb7d507cd9b7318566552d216113ce659
#   Stored in directory: c:\users\rishav\appdata\local\pip\cache\wheels\9f\a6\a1\898c991294471015f13c1e5b456fb8134c1af835db4dd93a7a
#   Building wheel for dash-auth (setup.py): started
#   Building wheel for dash-auth (setup.py): finished with status 'done'
#   Created wheel for dash-auth: filename=dash_auth-1.4.1-py3-none-any.whl size=476156 sha256=c0f0967452cec9dcf0b9a0aa62f17a9821a564998ac40dfa6f9914d49abc6a20
#   Stored in directory: c:\users\rishav\appdata\local\pip\cache\wheels\19\b2\02\3c3f05988ff92f02c52ce4e081859d423537e8e9b13f673c02
# Successfully built dtreeviz dash-auth
# Installing collected packages: oyaml, colour, py, atomicwrites, iniconfig, pluggy, pytest, dtreeviz, WTForms, flask-wtf, flask-simplelogin, chart-studio, flask-seasurf, dash-auth, ansi2html, jupyter-dash, explainerdashboard
# Successfully installed WTForms-2.3.3 ansi2html-1.6.0 atomicwrites-1.4.0 chart-studio-1.1.0 colour-0.1.5 dash-auth-1.4.1 dtreeviz-1.3 explainerdashboard-0.3.5 flask-seasurf-0.3.0 flask-simplelogin-0.0.7 flask-wtf-0.14.3 iniconfig-1.1.1 jupyter-dash-0.4.0 oyaml-1.0 pluggy-0.13.1 py-1.10.0 pytest-6.2.4

# %%
from sklearn.ensemble import RandomForestClassifier
from explainerdashboard import ClassifierExplainer, ExplainerDashboard
from explainerdashboard.datasets import titanic_survive, titanic_names

feature_descriptions = {
    "Sex": "Gender of passenger",
    "Gender": "Gender of passenger",
    "Deck": "The deck the passenger had their cabin on",
    "PassengerClass": "The class of the ticket: 1st, 2nd or 3rd class",
    "Fare": "The amount of money people paid", 
    "Embarked": "the port where the passenger boarded the Titanic. Either Southampton, Cherbourg or Queenstown",
    "Age": "Age of the passenger",
    "No_of_siblings_plus_spouses_on_board": "The sum of the number of siblings plus the number of spouses on board",
    "No_of_parents_plus_children_on_board" : "The sum of the number of parents plus the number of children on board",
}

X_train, y_train, X_test, y_test = titanic_survive()
train_names, test_names = titanic_names()
model = RandomForestClassifier(n_estimators=50, max_depth=5)
model.fit(X_train, y_train)

explainer = ClassifierExplainer(model, X_test, y_test, 
                                cats=['Deck', 'Embarked',
                                    {'Gender': ['Sex_male', 'Sex_female', 'Sex_nan']}],
                                cats_notencoded={'Embarked': 'Stowaway'}, # defaults to 'NOT_ENCODED'
                                descriptions=feature_descriptions, # adds a table and hover labels to dashboard
                                labels=['Not survived', 'Survived'], # defaults to ['0', '1', etc]
                                idxs = test_names, # defaults to X.index
                                index_name = "Passenger", # defaults to X.index.name
                                target = "Survival", # defaults to y.name
                                )

db = ExplainerDashboard(explainer, 
                        title="Titanic Explainer", # defaults to "Model Explainer"
                        shap_interaction=False, # you can switch off tabs with bools
                        )
db.run(port=8050)
# Out:
# Detected RandomForestClassifier model: Changing class type to RandomForestClassifierExplainer...
# Note: model_output=='probability', so assuming that raw shap output of RandomForestClassifier is in probability space...
# Generating self.shap_explainer = shap.TreeExplainer(model)
# Building ExplainerDashboard..
# Detected notebook environment, consider setting mode='external', mode='inline' or mode='jupyterlab' to keep the notebook interactive while the dashboard is running...
# Generating layout...
# Calculating shap values...
# Calculating dependencies...
# Calculating permutation importances (if slow, try setting n_jobs parameter)...
# Calculating predictions...
# Calculating roc auc curves...
# Calculating prediction probabilities...
# Calculating liftcurve_dfs...
# Calculating classification_dfs...
# Calculating pred_percentiles...
# Calculating pr auc curves...
# Calculating confusion matrices...
# Calculating metrics...
# Calculating ShadowDecTree for each individual decision tree...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# Starting ExplainerDashboard on http://192.168.224.244:8050
